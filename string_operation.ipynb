# %%
s1 = "Python is fun"

# %%
print(s1[0])
# Out:
# P

# %%
print(s1[-1])
# Out:
# n

# %%
print(len(s1))
# Out:
# 13

# %%
language = "Python"

# %%
version = "3.13"

# %%
print(language + version)
# Out:
# Python3.13

# %%
print(language + " " + version)
# Out:
# Python 3.13

# %%
print("Python"-"P") # here the subtraction operator will not work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 print("Python"-"P")
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %%
print("Python" * "P") # here the multiplication operator will not work
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 print("Python" * "P")
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
s2 = "Python"

# %%
print(s2 * 3) # Here * is repeattion operator
# Out:
# PythonPythonPython

# %%
print((s2 + " ") * 3) # In this way we can create space also.
# Out:
# Python Python Python

# %% [markdown]
# #### Membership operator
# ##### in
# ##### Checks if a value is present inside a sequence

# %%
s1 = "Python is fun"

# %%
print("Python" in s1) # Here the python is present so it give  the boolean as True.
# Out:
# True

# %%
print("i" in s1) # Here we can check if the single character is present or not.
# Out:
# True

# %%
print("z" in s1) # Same here aslo there is no z in s1 so the value is false.
# Out:
# False

# %%
print("Java" in s1) # There is no Java in s1.
# Out:
# False

# %% [markdown]
# ##### There is also another membership operator called as not in. It is just opposite of the in operator.

# %%
print("Java" not in s1) # there is no Java in s1 so the value is true.
# Out:
# True

# %%
print("P" not in s1) # There is P in the s1 so the output is false.
# Out:
# False

# %%
#comparison of strings

# %%
print("Python
