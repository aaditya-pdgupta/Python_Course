# %% [markdown]
# #### Creating file
# ##### A file is created using the open() function.
# ##### Syntax:
# #####        open("filename", "mode")
#
#
# #### File Creation Modes
# ##### 1. "x" Mode (Create only)
# ##### 2. "w" Mode (Create + Write)

# %%
open(f
