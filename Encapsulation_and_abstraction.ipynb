# %% [markdown]
# #### Encapsulation
# ##### Encapsulation is the process of binding data (variables) and methods (functions) together into a single unit called a class and restricting direct access to the data. It focuses on data hiding and security.

# %% [markdown]
# #### Abstraction
# ##### Abstraction means hiding internal implementation details and showing only essential features to the user. It focuses on what to do, not how to do.
