# %%
#### if-else statement in Python
##### if-else is used when you want to run one more block if the condition is True, and another block of the condition is false.
##### Syntax:
            if condition:
                statement1
# Out:
#   Cell In[1], line 4
#     if condition:
#     ^
# IndentationError: unexpected indent
