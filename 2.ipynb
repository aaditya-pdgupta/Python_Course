# %% [markdown]
# ### Print Function

# %%
num1 = 100

# %%
print(num1)
# Out:
# 100

# %%
print(num1) # Here we use the bracket to print.
# Out:
# 100

# %%
print(num1 # here it is showing the error because the bracket is not closed.
# Out:
#   Cell In[7], line 1
#     print(num1 # here it is showing the error because the bracket is not closed.
#                                                                                 ^
# SyntaxError: incomplete input

# %%
name = "John"

# %%
print(name)
# Out:
# John

# %%
age = 25

# %%
print(age)
# Out:
# 25

# %%
print(name , age ) # We can print the multiple value in same line just by using the comma.
# Out:
# John 25

# %%
print(name,age) # The sapce has no effect.
# Out:
# John 25

# %%
print(10,20,30) # It is called as separator and it is by default. We can change it also.
# Out:
# 10 20 30

# %%
print(10,20,30,40, sep=" ") # The sep help to decide the space whatever we do inside the comma that isi reflected. Here we have given the space so there is space in the output.
# Out:
# 10 20 30 40

# %%
print(10,20,30, sep=",") # Here we have given the comma so there is comma in the output.
# Out:
# 10,20,30

# %%
print(10,20,30, sep="") # Here we have not given the space so there is no space in the output.
# Out:
# 102030

# %%
print(10,20,30,40, sep="@") # Here there is @ inside the comma so there is @ between the two number.
# Out:
# 10@20@30@40

# %%
print(10,20,30, sep="hii") # Any valid can be kept between the comma or separator.
# Out:
# 10hii20hii30

# %%
print("Python') # If we start the string with the double quote and end with the single quote. Than there will be the syntax error.
# Out:
#   Cell In[33], line 1
#     print("Python') # If we start the string with the double quote and end with the single quote. Than there will be the syntax error.
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
num1 = 100

# %%
num2 = 200

# %%
num3 = 300

# %%
result = num1 + num2

# %%
print(num1, num2, num3)
# Out:
# 100 200 300

# %%
#Addition is the 100 and 200 is 300 should be my output

# %%
print("Addition of", num1, "and", num2, "is", result)
# Out:
# Addition of 100 and 200 is 300

# %%
name
# Out:
# 'John'

# %%
age
# Out:
# 25

# %%
#Name:John Age: 20 I need to print this

# %%
print("Name:", name, "Age:", age)
# Out:
# Name: John Age: 25

# %%
#Name:John , Age: 20 Now i want to print this

# %%
print("Name:", name, sep="," , "Age:", age)  # Here it is error because sep should be used in last
# Out:
#   Cell In[59], line 1
#     print("Name:", name, sep="," , "Age:", age)  # Here it is error because sep should be used in last
#                                               ^
# SyntaxError: positional argument follows keyword argument

# %%
print("Name:", name, ", Age:", age) # If we use sep than for evry character it put  comma so we used this.
# Out:
# Name: John , Age: 25

# %%
day = 10

# %%
month = 3

# %%
year = 2020

# %%
#I want to print 10/3/2020

# %%
print(day, month, year, sep="/")
# Out:
# 10/3/2020

# %% [markdown]
# ### Input Function
# input() is a built in Python function used to take input from the user.

# %%
name = "mark"

# %%
print(name)
# Out:
# mark

# %%
first_name = input () #The input is given as John below.
# Out:
#  John

# %%
print(first_name)
# Out:
# John

# %%
age = input() # here we have given the input as age.
# Out:
#  25

# %%
print(age) # We can see the output here.
# Out:
# 25

# %%
first_name = input("Enter your name")0
# Out:
# Enter your name john

# %%
print(first_name)
# Out:
# first_name

# %%
age = input("How old are you?")
# Out:
# How old are you? 20

# %%
num1 = input("Enter a number:")
# Out:
# Enter a number: 10

# %%
num2 = input ("Enter another number:")
# Out:
# Enter another number: 21

# %%
print(num1)
# Out:
# 10

# %%
print(num2)
# Out:
# 21

# %%
result = num1 + num2

# %%
print(result) # Output is giving 1021 instead of 31. This is because the input is in string and the its joins the two string not add the number.
# Out:
# 1021

# %%
type(num1)# The input is always string so according to the need we have to convert.
# Out:
# str

# %%
type(num2)
# Out:
# str

# %%
int(num1)

# %%
int(num2)

# %%
result = int(num1) + int(num2) # here we have changed the string into the integer and now the output is as desired.

# %%
print(result)
# Out:
# 31

# %%
year = input("What is the current year?")
# Out:
# What is the current year? 2025

# %%
age = input("What is your age?")
# Out:
# What is your age? 18

# %%
#You were born in the year 2027

# %%
born_year = int(year) - int(age) # Here the input is in the foerm of the string so we converted in the integer and does operation.

# %%
print("You were born in the year", born_year)
# Out:
# You were born in the year 2007
