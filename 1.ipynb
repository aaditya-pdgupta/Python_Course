# %% [markdown]
# ## Literal in Python

# %%
100 # It is the integer that contain the whole number which can be the negative, zero or positive number.
# Out:
# 100

# %%
-55
# Out:
# -55

# %%
"Hello" # It is the string which must be always in the quaotation so it can be printed.
# Out:
# 'Hello'

# %%
'Hello'
# Out:
# 'Hello'

# %%
"Hello Everyone, we are learning Python"
# Out:
# 'Hello Everyone, we are learning Python'

# %%
"""Hello,
How are you?
We are learning Python."""
# Out:
# 'Hello,\nHow are you?\nWe are learning Python.'

# %%
True
# Out:
# True

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
True # Boolean expression, that give the value as True or False
# Out:
# True

# %%
False
# Out:
# False

# %%
None

# %% [markdown]
# ## Variable in Python

# %%
a=1

# %%
print(a)
# Out:
# 1

# %%
a
# Out:
# 1

# %%
b=2

# %%
print(b)
# Out:
# 2

# %%
c=3

# %%
print(c)
# Out:
# 3

# %%
d=a+b+c

# %%
print(d)
# Out:
# 6

# %%
del d

# %%
print(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 print(d)
#
# NameError: name 'd' is not defined

# %%
print(a)
# Out:
# 1

# %%
print(b)
# Out:
# 2

# %%
print(c)
# Out:
# 3

# %%
x=5

# %%
print(x)
# Out:
# 5

# %%
x=3

# %%
print(x)
# Out:
# 3

# %%
y=1

# %%
z=x*y

# %%
print(z)
# Out:
# 3

# %%
a="python"

# %%
print(a)
# Out:
# python

# %%
a=1

# %%
print(a)
# Out:
# 1

# %%
_a=1

# %%
print(_a)
# Out:
# 1

# %%
5=1
# Out:
#   Cell In[103], line 1
#     5=1
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
age=50

# %%
print(age)
# Out:
# 50

# %%
a1="Hello"

# %%
a2=" World"

# %%
a3=a1 + a2

# %%
print(a3)
# Out:
# Hello World

# %% [markdown]
# ## Keywords in Python

# %% [markdown]
# ### It is the reserved word that has a predifined meaning in the language.

# %%
 import keyword

# %%
keyword.kwlist # This can be used to view the available keywords
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# ## Primitive Datatypes

# %% [markdown]
# ### Integer

# %%
age =  25

# %%
age
# Out:
# 25

# %%
print(age)
# Out:
# 25

# %%
type(age) # This is the way to know what type of data is
# Out:
# int

# %% [markdown]
# ### Float

# %%
percent = 87.5

# %%
type(percent)
# Out:
# float

# %%
10+20
# Out:
# 30

# %%
3.5+2.22
# Out:
# 5.720000000000001

# %%
4+3.5
# Out:
# 7.5

# %% [markdown]
# ### String

# %%
name = "Mark"

# %%
type(name)
# Out:
# str

# %%
full_name = "Ram Shyam"

# %%
full_name
# Out:
# 'Ram Shyam'

# %%
type(full_name)
# Out:
# str

# %% [markdown]
# ### Boolean

# %% [markdown]
# #### It has only two value: True or False

# %%
vall = True ## Here the T of True must be always capital

# %%
type(vall)
# Out:
# bool

# %%
vall2 = False ## Same F must be capitall too

# %% [markdown]
# ### None

# %%
vall3 = None ## Here also the N should be capital

# %%
type(vall3)
# Out:
# NoneType

# %%
s1 = "Hello World"

# %%
s1
# Out:
# 'Hello World'

# %%
s2 = 'Hello World'

# %%
type(s2)
# Out:
# str

# %%
s3 = """Hello everyone.
We are looking at strings.
Bye"""

# %%
s3          # the output is shown in the single one line. WHere every new line is represented by the the \n.
# Out:
# 'Hello everyone.\nWe are looking at strings.\nBye'

# %%
type(s3)
# Out:
# str

# %% [markdown]
# #### What is the length of String?
# ##### It mean how many characters are there in the string.

# %%
s4 = "Python" # Here Python has 6 character or alphabets. So its length is 6.

# %%
len(s4) # Here the len is used to find the length.
# Out:
# 6

# %%
s1
# Out:
# 'Hello World'

# %%
len(s1) # Here the length of the s1 is 11. Here the space is counted as the valid character. So there is 10 alphabets and one space which altogther make 11.
# Out:
# 11

# %% [markdown]
# ### Indexing
# #### Here, in string every character has its own position. Indexing means accessing individuals elemements from a sequence like strig, list tuple etc. It tells  the Python which position you want to acccess.

# %%
s4[0] # Indexing always start from 0. So here 0 represent the P.
# Out:
# 'P'

# %%
s4[2] # 2 mean the t.
# Out:
# 't'

# %%
s4[5] # 5 mean the n.
# Out:
# 'n'

# %%
s4[6] # Here there is no length 6. So to know the index we can just use len and -1 (len-1) from that.
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 s4[6]
#
# IndexError: string index out of range

# %%
len(s1)
# Out:
# 11

# %%
s1[10]
# Out:
# 'd'

# %%
s1[-1] # Using the negative indexing we can fetch. Like in negative indexing it satrt from last as -1. So -l is the total index number.
# Out:
# 'd'

# %% [markdown]
# ### Joining of the two string

# %%
s1 + s2 # Here using + will give only the addition without space.
# Out:
# 'Hello WorldHello World'

# %%
s1 + ' ' +s2 # Here using the comma give the space.
# Out:
# 'Hello World Hello World'

# %% [markdown]
# ### Type conversion/ Type casting
# #### The process of converting variable from one data type to another.

# %%
num1 = 100

# %%
type(num1)
# Out:
# int

# %%
float(num1) # Here the integer is shown in the form of integer but the value of the num1 remain integer.
# Out:
# 100.0

# %%
num2 = float(num1)

# %%
num2
# Out:
# 100.0

# %%
type(num2)
# Out:
# float

# %%
type(num1)
# Out:
# int

# %%
num1 = float(num1) # Here the value of num1 has been converted in the float.

# %%
type(num1)
# Out:
# float

# %%
num3 = 55.2

# %%
type(num3)
# Out:
# float

# %%
int(num3) # Here it is the only equivalent of the float not the permanent stored value.
# Out:
# 55

# %%
num3
# Out:
# 55.2

# %%
num3=int(num3) #Here it is converted and stored in the num3 as the integer.

# %%
num3
# Out:
# 55

# %%
num4=77.4

# %%
type(num4)
# Out:
# float

# %%
num4=int(num4)

# %%
num4
# Out:
# 77

# %%
num5=77.85

# %%
num5=int(num5)

# %%
num5
# Out:
# 77

# %%
str(num5) # Here integer has been converted but for temporary.
# Out:
# '77'

# %%
num5
# Out:
# 77

# %%
num5=str(num5) #Here the integer has been converted as storde in num5 permanently.

# %%
num5
# Out:
# '77'

# %%
type(num5)
# Out:
# str

# %%
s1 = "hello"

# %%
s1
# Out:
# 'hello'

# %%
int(s1) # Here it is the character inside the string so it can not be converted the string.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[178], line 1
# ----> 1 int(s1)
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
float(s1) # Here again there is character inside the string so it can not be converted into the the float.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 float(s1)
#
# NameError: name 's1' is not defined

# %%
s2 = '12345'

# %%
type(s2)
# Out:
# str

# %%
int(s2)
# Out:
# 12345

# %%
y = int(s2) # Here the value is just converted but the stored in the y.

# %%
s2
# Out:
# '12345'

# %%
s2=y # Here the value has been stored in the s2 as int.

# %%
s2
# Out:
# 12345

# %%
s3 = 55.33

# %%
float(s3)
# Out:
# 55.33

# %%
type(s3)
# Out:
# float

# %%
s4 = "Python3.14"

# %%
float(s4) # Here there is character so it can't be converted. To convert there should be only pure digit and decimal.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 float(s4)
#
# ValueError: could not convert string to float: 'Python3.14'

# %%
s5 = '1234a'

# %%
int(s5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 int(s5)
#
# ValueError: invalid literal for int() with base 10: '1234a'

# %%
language = "Python"

# %%
version = 3.13

# %%
language + version #Here the language has string where the + mean joining of the two string where the version has float so in float + is just sum. So the python get confused.
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 language + version
#
# TypeError: can only concatenate str (not "float") to str

# %%
language + str(version) # Here we can first convert the version into string than join them.
# Out:
# 'Python3.13'

# %%
'100'+'100' #  Here we are not getting 200 because they are inside quote mean they are string so they are only joined not sum.
# Out:
# '100100'

# %%
int(100) + int  (100) # Now here we have converted in the int and the output is 200.
# Out:
# 200

# %%
str(100)
# Out:
# '100'

# %%
str(100.2)
# Out:
# '100.2'

# %%
int('2222')
# Out:
# 2222

# %%
float("23")
# Out:
# 23.0

# %% [markdown]
# #### Type casting for boolean

# %%
val1 = True
val1
# Out:
# True

# %%
str(val1) # Here we have converted the boolean val1 into the integer.
# Out:
# 'True'

# %%
bool('Python')
# Out:
# True

# %%
bool(100)
# Out:
# True

# %%
bool('23.3')
# Out:
# True

# %%
bool(0) # Here bool of zero gives the false.
# Out:
# False

# %%
bool(0.0)
# Out:
# False

# %%
bool(-100) # For every bool gives the true except zero.
# Out:
# True

# %%
bool(0.5)
# Out:
# True

# %%
bool('Python')
# Out:
# True

# %%
bool('a')
# Out:
# True

# %%
bool(" ")  # Here there is the space so it is recognized as character in the string so there is true value for it.
# Out:
# True

# %%
bool('')# Here there is no space between the quote so it gives the false. It is also called as Empty String.
# Out:
# False

# %% [markdown]
# #### Type casting for the None

# %%
bool(None) # Here for None it is also false.
# Out:
# False

# %%
int(2)
# Out:
# 2

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
str(False)
# Out:
# 'False'

# %%
str(True)
# Out:
# 'True'

# %%
str(None)
# Out:
# 'None'

# %% [markdown]
# ### Operators

# %%
x = 10

# %%
y = x + 20 # Here the x and y are the variable and + and = are the operators. 20 is a value. The value and variable are called operands.

# %% [markdown]
# ####  Arithmetic Operators
# It perform the basic mathematical operation.

# %%
num1 = 10

# %%
num2 = 5

# %%
num1 + num2 # Addition Operator
# Out:
# 15

# %%
num1 - num2 # Subtraction operator
# Out:
# 5

# %%
num1 * num2 # Multiplication Operator
# Out:
# 50

# %%
num1/num2 #Division, but the output is float.
# Out:
# 2.0

# %%
num1//num2 # Floor Divison Operator. Its removes the ramainder and give only the integer value.
# Out:
# 2

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
10 // 3
# Out:
# 3

# %%
10 % 3 # Modulus or Percent operator gives the remainder as the output.
# Out:
# 1

# %%
num1 % num2
# Out:
# 0

# %%
2 ** 3 # Exponent or Power Operator. It basically gives the power.
# Out:
# 8

# %% [markdown]
# #### Assignment Operator
# Used to assign the values to variables.

# %%
value = 1000 # Here the = is the assignment operator.

# %%
add = num1 + num2

# %%
add
# Out:
# 15

# %%
x = 10

# %%
x += 1 # Here += is used, which mean the 1 is added to the existing value of the x which mean the 10 is the beginning value now 1  is added and become 11.

# %%
x
# Out:
# 11

# %%
 x -= 6

# %%
x # # Here -= is used, which mean the 6 is subtracted to the existing value of the x which mean the 10 is the beginning value now 6 is subtracted and become 5.
# Out:
# 5

# %%
x *= 10 # Here *= is used, which mean the 10 is multiplied to the existing value of the x which mean the 5 is the beginning value now 10 is multiplied and become 50.

# %%
x
# Out:
# 50

# %%
x /=20 ## Here /= is used, which mean the 50 is divided to the existing value of the x which mean the 50 is the beginning value now 20  is used to divided and become 2.5.

# %%
x
# Out:
# 2.5

# %% [markdown]
# #### Comparison Operators
# Used to compare  two values
# Always return True or False

# %%
num1 = 100

# %%
num2 = 90

# %%
num3 = 90

# %%
num2 == num3 # Here it is equality operator checkif the two variable are equal or not.Here they are equal so it give True output
# Out:
# True

# %%
num1 == num2 # Here the two variable are not equal. Hence this give the output as False.
# Out:
# False

# %%
'Python' == 'python' # We have checked with the string also.
# Out:
# False

# %%
'python' == 'python' # here they are same so value is true.
# Out:
# True

# %%
num1 != num2 # It is not equal to operator. So here we checked if the num1 is not equal to num2 and the output is tru.Mean they both are not equal.
# Out:
# True

# %%
num2 != num3 # here the num2 and num3 are equal so it give the output as the false.
# Out:
# False

# %%
num1 > num2  #It is the greater than operator. Check which is greater. Here num1 is greater than num2 so the ans is True.
# Out:
# True

# %%
num1 < num2  # It is the less than operator. Here the num1 is greater than the num2 so the ans is false.
# Out:
# False

# %%
num1 >= num2 # It is the greater or equal to perator.So it check the whether the given value is greater or equal.If this staisfy the condition than it give ouput as the true.
# Out:
# True

# %%
 num2 >= num3 # Here the num2 is not greater but equal to num3 are equal so the output is True.
# Out:
# True

# %%
num2 >= num1 # Here the num2 is neither greater than num 1 or nor equal to num1. So the output is False.
# Out:
# False

# %% [markdown]
# #### Logical Operators
# Used in conditions and decision making.

# %% [markdown]
# #### AND operator

# %%
True and True # Here and is a Logical Operator. So there is basically two condition. If the both is true than the output will be true if anyone of it false then the output will be` false.
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
False and False # Here the both the logic is false so the output is false.
# Out:
# False

# %% [markdown]
# #### OR Operator

# %%
True or True # Here Or is a logical Operator. So, if anyone among two operand anyone is true the output will be true else.
# Out:
# True

# %%
True or False # Here first operand is true so the output is true.
# Out:
# True

# %%
False or True # Here last operand is true so the output is true.
# Out:
# True

# %%
False or False # Here the both operand is False so the entire output will be the false.
# Out:
# False

# %%
name = "Mark"

# %%
age = 25

# %%
name == "Mark" and age >= 18 # Here we name check whether the mark is equal and age is greater than or qual to 18. And this both condition is satisfied so the output is true.
# Out:
# True

# %%
name =="Mark" and age == 30 # Here one condition is satisfied but another is not satisfied so the output is false.
# Out:
# False

# %%
name == 'Mark' or age == 30 # Here the one cond is satisfied and other is not than the output is True.
# Out:
# True

# %% [markdown]
# ### Precendence Operator
# It means which operator is evaluated first when an expression has multiple operators. Like BODMAS for Python

# %%
5 + 10 * 6 # Here there is two operator sum and multiplication so first the multiplication is done and then the sum.
# Out:
# 65

# %%
name = "Mark"

# %%
age = 25

# %%
name == "Mark" or name =="John" and age < 18 # Here the and is considered first and or later.
# Out:
# True

# %%
(name == "Mark" or name =="John") and age < 18 # Here to operate the or first we can use the bracket.
# Out:
# False

# %%
(5 + 10) * 6
# Out:
# 90

# %% [markdown]
# ### Associativity
# When there is two same operator in same line and same priority but the associativity will decide whether left to right or right to left.

# %%
100 / 10 * 10 # Here both multiplication and division lies in same line so it moves from left to right.
# Out:
# 100.0

# %%
2 ** 1 ** 3 # Both have same operator so the Right to left.
# Out:
# 2

# %% [markdown]
# ### Classification of the Operator based on the operands.

# %% [markdown]
# #### Urinary Operator
# If an operator operate on only one operand.

# %%
-10
# Out:
# -10

# %%
not True
# Out:
# False

# %% [markdown]
# ##### Binary Operator
# These are the operator that operates on two operands.

# %%
10 - 5
# Out:
# 5

# %%
True or False
# Out:
# True

# %% [markdown]
# #### Ternary Operator
# The operator that operates on three operand.
