# %%
class A:
    def add(self, num1, num2): # Here in this add function we have argument num1 and num2.
        return num1 + num2

# %%
    def add(self, num1, num2, num3): 3 # Here we have same function with the three argument.
