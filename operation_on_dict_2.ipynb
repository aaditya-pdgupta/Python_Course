# %%
d1 = {[1,3,5]:  9, [1,2,1]: 4}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 d1 = {[1,3,5]:  9, [1,2,1]: 4}
#
# TypeError: unhashable type: 'list'
