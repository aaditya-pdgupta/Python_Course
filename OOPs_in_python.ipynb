# %% [markdown]
# #### OOPs in Python
# ##### Object-Oriented Programming (OOP) is a programming approach that models real-world entities as objects, which contain data (variables) and behavior (methods).
# ##### There is :
# ##### 1--> Classs
# #####      A class is a template (blueprints) that tells: what data to store and what actions are allowed.
#
# ######       Syntax:
#                     class Car:
#                        pass
#
# ##### 2--. Object
# #####       An object is real thing created from a class. It actually exists in memory and can be used.
#
# ##### Why do you need ?
# To organize code
#
# To reuse code
#
# To manage large programs
#
# To make code easy to understand

# %%
# Object----> a container.
# data ---> attributes
# functionality ---> methods/behaviors

# %%
fruits = ["mango", "apple", "orange"]

# %%
print(type(fruits))
# Out:
# <class 'list'>

# %%
#fruit is an object of a class.
fruits.append("grapes") # Here the append is a method.

# %%
print(fruits)
# Out:
# ['mango', 'apple', 'orange', 'grapes']

# %% [raw]
# """
# car1
#      ----> brand = "BMW", model = "XYZ12", year = 2025"
#      -----> accelerates, brake
#     dot notation(.)
#     car1.brand ---> "BMW"
#     car1.acceleratio
#
# """"
