# %% [markdown]
# #### Module in Python
# ##### A module in Python is a file that contains Python code (functions, variables, classes) which can be reused in another program. .py file is a module.
#
# ##### 🔹 Why use Modules?
#
# Code becomes organized
#
# Reusability of functions
#
# Easier debugging & maintenance
#
# Avoids writing the same code again
#
# ##### Types of Modules in Python:

# %% [markdown]
# #### 1. Built in Modules
# #####    These are already available in Python like math, random, datetime, sys etc.

# %%
#Syntax: import module_name
#Syntax for importing only few functions/variables: from module_name f1, f2,
