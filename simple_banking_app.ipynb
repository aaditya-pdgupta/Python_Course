# %%
kyc_docs = {}

# %%
def check_balance():
    print(f"Your current balance is {balance}")

# %%
def deposit(amount):
    global balance
    if amount > 0:
        balance += amount
    else:
        print("cannot deposit a negative or 0 amount")

# %%
def withdraw(amount):
    global balance
    if amount <= 0:
        print("Cannot withdraw negative or zero amount")
    elif amount > balance:
        print("Cannot withdraw. Insufficient balance.")
    else:
         balance -= amount

# %%
def kyc(**docs):
    if len(kyc_docs) == 0:
        print("KYC has not been done")
    global kyc_doc
    kyc_documents.update(docs)

# %%
def check_kyc():
    for docs in kyc_docs:
        print(f"{doc}: {kyc_docs[docs]}")

# %%
balance = 0 # It is a initial balance.

# %%
print("Welcome to the abc Bank")
# Out:
# Welcome to the abc Bank

# %%
while True:
    print("1.Check your balance")
    print("2.Deposit an amount")
    print("3.Withraw an amount")
    print("4.Check KYC")
    print("5.Upadate Kyc")
    print("6.Quit")
    choice = (input("Enter your choice (1-4):"))

    if choice == '1':
        check_balance()
    elif choice == '2':
        amt = float(input("Enter the amount to deposit:"))
        deposit(amt)
        print(f"Amount {amt} has been deposited in your account successfully.")
    elif choice == '3':
        amt = float(input("Enter the amount to withdraw:"))
        withdraw(amt)
        print(f"Amount {amt} has been withrawn from your account successfully.")
    elif choice == '4':
        if len(kyc_doc) == 0:
            print("KYC not done")
    elif:
        
        break
    else:
        print("Invalid choice!! Re-try.")


print("Thank you for banking with us")
# Out:
# 1.Check your balance
# 2.Deposit an amount
# 3.Withraw an amount
# 4.Quit
# Enter your choice (1-4): 4
# Quiting have a nice day!!
# Thank you for banking with us
