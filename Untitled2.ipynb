# %% [markdown]
# #### Abstract Class
# ##### An abstract class is a class that cannot be instantiated (object can not be created) and is used to define a blueprint for other classes. It contains abstract methods (methods without im
