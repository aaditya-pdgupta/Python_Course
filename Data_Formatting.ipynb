# %% [markdown]
# #### Data Formatting
# ##### Data Formatting is the process of changing the apperance, structure or data type of data without changing its meaning, so it becomes consistent, readable and alrea
