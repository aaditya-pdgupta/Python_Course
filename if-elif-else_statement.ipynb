# %% [markdown]
# #### if-elif-else Statement
# ##### It is used when we have multiole conditions and want to choose only one block to execute.
# ##### syntax:
#             if condition1:
#                 statement1
#             elif condition2:
#                 statement2
#             elif condition3:
#                 statement3
#             else
#                 statement4

# %%
marks = float(input("Enter your marks:"))
# Out:
# Enter your marks: 89.5

# %%
if marks >= 90:
    print("Your grade is A+.")
elif marks >= 80:
    print("Your grade is A.")
elif marks >= 70:
    print("Your grade is B+")
elif marks >=60:
    print("Your grade is B.")
else:
    print("Your grade is F.")
# Out:
# Your grade is A.
