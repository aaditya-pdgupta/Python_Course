# %% [markdown]
# #### Set in Python
# ##### Characteristics
# ##### 1. Unordered
#         -Elements have no fixed position.
#         -Output order may chnage each time.
# ##### 2. No Duplicates
#         -Automatically removes repeated
