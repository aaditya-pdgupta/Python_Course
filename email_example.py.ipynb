# %% [raw]
# Alice alice-cool_123@example.com 986662220002
# Carol Carol_123@example.com 988822223
# John john.dan.12345@domain.com 9999999999
# Invalids emails are:
# -@example.com

# %%
import re

# %%
pattern = r"[a-zA-Z0-9_.-]+[@]example.com"
