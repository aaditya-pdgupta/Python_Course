# %%
# Creating a class
class My_Class:
    pass        # Pass is used to define an empty class or blocj without causing an error.

# %%
# Creating an  Object

obj1 = My_Class()
obj2 = My_Class()

# obj1 and obj2 are objects of class My_Class

# %%
l1 = [1, 2, 2]

# %%
print(type(l1))
# Out:
# <class 'list'>

# %%
print(type(obj1)) # Here we are getting the 
print(type(obj2))
# Out:
# <class '__main__.My_Class'>
# <class '__main__.My_Class'>
