# %%
# Creating a class
class My_Class:
    pass        # Pass is used to define an empty class or blocj without causing an error.

# %%
# Creating an  Object

obj1 = My_Class()
obj2 = My_Class()

# obj1 and obj2 are objects of class My_Class

# %%
l1 = [1, 2, 2]

# %%
print(type(l1))
# Out:
# <class 'list'>

# %%
print(type(obj1)) # Here we are getting the startig and ending with the double under score means they are dunder. Python calls them automatically.
print(type(obj2))
# Out:
# <class '__main__.My_Class'>
# <class '__main__.My_Class'>

# %%
# Calling methods using objects?
#obj1.method(arg1, arg2)

# %%
class Student:
    """ 
    This is a Class Student to manage student information and activities.
    """
    pass

# %%
s1 = Student() # Here we have created a two object s1 and s2.
s2 = Student()

# %%
# Doc Strings ==> __doc__
print(Student.__doc__)
# Out:
#
#     This is a Class Student to manage student information and activities.

# %%
print(help(Student))
# Out:
# Help on class Student in module __main__:
#
# class Student(builtins.object)
#  |  This is a Class Student to manage student information and activities.
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#
# None
