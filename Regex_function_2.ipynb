# %% [markdown]
# ##### sub()
# ##### sub() is used to replace parts of a string that match a regular expressions.
#
# ##### Syntax:
# ##### re.sub(pattern, replacement, string)

# %%
import re

# %%
s1 = "Sunday, Monday, Tuesday, Monday, Sunday"

# %%
pat = "Sunday"

# %%
replacement = "Friday"

# %%
result = re.sub(pat, replacement, s1)

# %%
print(result) # Here we can see wherever there was Sunday it has been replaced by the Friday.
# Out:
# Friday, Monday, Tuesday, Monday, Friday

# %%
# Suppose we want to replace only 1 than.

# %%
pat = "Sunday"

# %%
replacement = "Friday"

# %%
result = re.sub(pat, replacement, s1, count = 1)

# %%
print(result) # Here only one Sunday has been replaced and that is the first occurence.
# Out:
# Friday, Monday, Tuesday, Monday, Sunday

# %%
# Suppose we don't know actually what to be replaced than

# %%
pat = r"S[a-z]+"

# %%
replacement = "Saturday"

# %%
result = re.sub(pat, replacement, s1)

# %%
print(result)
# Out:
# Saturday, Monday, Tuesday, Monday, Saturday

# %%
message = """We are learning re. Using re, we can search for a pattern in a given string.
Using the sub(), we can replace the pattern with a givem string as well."""

# %%
patt = r"\bre\b" # Here we are using the boundary.

# %%
replace = "regular expression"

# %%
res =  re.sub(patt, replace, message)

# %%
print(res)
# Out:
# We are learning regular expression. Using regular expression, we can search for a pattern in a given string.
# Using the sub(), we can replace the pattern with a givem string as well.

# %%
# Let suppose we have both re and Re and want to replace it with the regular expression than.

# %%
info = """We are learning re. Using Re, we can search for a pattern in a given string.
Using the sub(), we can replace the pattern with a given string as well."""

# %%
pattt = r"\bre\b"

# %%
replac = "Regular Expression"

# %%
ress =  re.sub(pattt, replac, info, flags=re.IGNORECASE) # Here flags will ignore the lower and upper casee.

# %%
print(ress)
# Out:
# We are learning Regular Expression. Using Regular Expression, we can search for a pattern in a given string.
# Using the sub(), we can replace the pattern with a given string as well.

# %%
phone_nums = "+91-8888888, +91-777777"

# %%
pattern = r"[+-]" # Here we are replacing the + and - sign.

# %%
replacement = ""

# %%
res = re.sub(pattern, replacement, phone_nums)

# %%
print(res)
# Out:
# 918888888, 91777777
