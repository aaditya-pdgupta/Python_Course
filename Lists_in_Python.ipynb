# %% [markdown]
# #### List in Python
# ##### A list is a data structure in Python used to store multiple items in a single variable. Items can be of any data type (integer, strings, floats, other lists, etc.)
#
# ##### Syntax:
#         my_list = [item1, item2, item3,.....]

# %%
name = "John"

# %%
age = 20

# %%
percent = 85.5

# %%
student = ["John", 20, 85.5] # Here we can store the data in one list

# %%
print(student) # Here the output is in on
# Out:
# ['John', 20, 85.5]
