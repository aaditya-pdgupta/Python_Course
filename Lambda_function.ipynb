# %% [markdown]
# #### Lambda(Anonymous) Functions
# ##### A lambda function (also called anonymous function) is a small, one line function without a name.
#
# ##### Syntax:
#             lambda arguments : expression

# %%
def add(a):
   # return a+1

# %%
res = add(1)

# %%
print(res)
# Out:
# 2

# %%
# Using the lambda.

# %%
fun = lambda a : a + 1 # Here we are using the lambda without using the function

# %%
result = fun(2)

# %%
print(result)
# Out:
# 3

# %%
# Now lets do passing two arguments.

# %%
function = lambda a,b : a + b

# %%
res = fun
