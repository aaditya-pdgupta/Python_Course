# %%
countries = ["Nepal", "United States", "Australia", "Ireland", "Srilanka", "Iceland", "Cuba", "Iran", "Poland"]

# %%
counter = 0

# %%
# Count all the countries which are starting with N.

# %%
for country in countries:
    if country[0] == "N":
        counter = counter + 1
        
print(f" The numberof countries starting with N is {counter}")
# Out:
#  The numberof countries starting with N is 1

# %%
# There is also another way to do with start.with

# %%
count = 0

# %%
for country in countries:
    if country.startswith("N"):
        count = count + 1
        
print(f" The number of countries starting with N is {counter}")
# Out:
#  The number of countries starting with N is 1

# %%
# I need the list of the output also.

# %%
count = 0
output = []

# %%
for country in countries:
    if country.startswith("N"):
        count = count + 1
        output.append(country)
        
print(f" The number of countries starting with N is {counter}")
print(f" The name of the country starting with N is {output}")
# Out:
#  The number of countries starting with N is 1
#  The name of the country starting with N is ['Nepal']
