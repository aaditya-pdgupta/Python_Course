# %% [markdown]
# #### Compile ()
# ##### re.compile is used to compile a regular expression into a pattern object, which can be reused multipile times.
# ##### Syntax:
# ##### re.compile(pattern, flags=0)

# %%
import re

# %%
phones = "Alice-123456254, Mark-7887887888, Carol-123578887"

# %%
pattern = r"\d{10}"# Exactly 10 digits

# %%
pattern_compiled = re.compile(pattern)

# %%
match_obj = re.findall(pattern, phones)

# %%
print(match_obj)
# Out:
# ['7887887888']

# %%
#student_details =

# %%
with open("student_details.txt", "r") as fh:
    data = fh.read()

# %%
print(data)
# Out:
# Alice alice@example.com 986666666222
# Carol carol@example.com 123456789
# John john@example.com 232323232

# %%
phone_matches = re.finditer(pattern_compiled, data) # Here we are using the above the compiled before.

# %%
print(phone_matches)

# %%
for matches in phone_matches: # Using this instead of getting the list we get the span also.
    print(matches)
# Out:
# <re.Match object; span=(24, 34), match='9866666662'>
