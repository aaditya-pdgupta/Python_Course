# %%
pswd = "admin123"
attempt = 3
num = 0
logged = False

# %%
while num < 3:
    print(f"The number of the attempt remaining is {attempt}")
    user_pswd = input("Enter the passwod:")
    if user_pswd == pswd:
        print("Congrats! You entered a correct password")
        logged = True
        break
    else:
        print("Incorrect password, Try again...")
        num += 1
        attempt -= 1
if logged == False:
    print("To many attempt, you have been blocked...")
else:
    print("You have an access now, Enjoy!!")
# Out:
# The number of the attempt remaining is 3
# Enter the passwod: 2
# Incorrect password, Try again...
# The number of the attempt remaining is 2
# Enter the passwod: admin123
# Congrats! You entered a correct password
# You have an access now, Enjoy!!

# %%
correct_num = 23
attempt = 10
num = 0
guess = False

# %%
correct_num = 23
attempt = 10
num = 0
guess = False

# %%
while num < 10:
    print(f"You have {attempt} attempts remaining!!")
    user_num = float(input("Enter your guessed number"))
    if user_num == correct_num:
        print("You are genius, Congrats !!")
        guess = True
        break
    else:
        if user_name > correct_num:
            high_low = "lower"
        else:
            high_low = "higher"
            print(f"You guess is near about, Try {high_low} number")
            num += 1
            attempt -= 1

if guess == False:
    print("Bad luck, you have exceed the attempt, try again....")

    
print(f"The secret number is {correct_num}")
# Out:
# You have 10 attempts remaining!!
# Enter your guessed number 23
# You are genius, Congrats !!
# The secret number is 23
