# %% [markdown]
# #### ^ (Caret Symbol)
# ##### It has two different meanings depending on where it is used.
# ##### 1. ^ at the START of a pattern means start of string.
# ##### 2. ^ INSIDE square brackets [ ] menas NOT / negation

# %%
import re

# %%
s1 = "Python is a programming language."

# %%
pat = r"[a-z]{8}
