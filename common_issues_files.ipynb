# %%
fh = open("Practice.txt", "r") # We have to use the correct path as well as the correct file name.

# %%
contents = fh.read()

# %%
fh.close()

# %%
print(contents)
# Out:
# This is a test file.
# We are learning file handling in the python.
# Modes to open a file are: r, w, a, t, b
# This has content has been written using the 'a' mode.'n'a' mode is used to add new content at the end of the file.
# Good bye!

# %%
# Let see we are opening the file in read mode and trying to write over it.

# %%
open("Practice.txt", "r")
# Out:
# <_io.TextIOWrapper name='Practice.txt' mode='r' encoding='cp1252'>
