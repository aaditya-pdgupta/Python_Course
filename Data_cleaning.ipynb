# %%
import pandas as pd
df = pd.read_excel("Four_Column_Data.xlsx")

# %%
print(df)
# Out:
#    ID   Name   Department  Score
# 0   1    Ram  Electronics     85
# 1   2  Rahul   Biomedical     78
# 2   3  Shyam     Computer     92
# 3   4   Hari   Electrical     88
# 4   5  Karan   Mechanical     74
# 5   6  Gopal  Electronics     90

# %%
df.head(3)
# Out:
#    ID   Name   Department  Score
# 0   1    Ram  Electronics     85
# 1   2  Rahul   Biomedical     78
# 2   3  Shyam     Computer     92

# %%
headers = ["S.No", "Even", "Odd", "Multiples"]
df.columns = headers

# %%
print(df)
# Out:
#    S.No   Even          Odd  Multiples
# 0     1    Ram  Electronics         85
# 1     2  Rahul   Biomedical         78
# 2     3  Shyam     Computer         92
# 3     4   Hari   Electrical         88
# 4     5  Karan   Mechanical         74
# 5     6  Gopal  Electronics         90
