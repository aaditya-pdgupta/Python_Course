# %%
import pandas as pd
df = pd.read_xlsx("Excel_dataset.xlsx")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_xlsx("Excel_dataset.xlsx")
#
# AttributeError: module 'pandas' has no attribute 'read_xlsx'
