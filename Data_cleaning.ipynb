# %%
import pandas as pd
df = pd.read_excel("Monthly_Sales_Data.xlsx")

# %%
print(df)
# Out:
#          Date  Product Name     Category  Quantity Sold  Unit Price  \
# 0  01-01-2025        Laptop  Electronics              5       55000
# 1  03-01-2025  Mobile Phone  Electronics             10       18000
# 2  05-01-2025    Headphones  Accessories             15        2500
# 3  07-01-2025      Keyboard  Accessories              8        1500
# 4  10-01-2025       Monitor  Electronics              6       12000
# 5  12-01-2025         Mouse  Accessories             20         800
# 6  15-01-2025        Tablet  Electronics              4       22000
# 7  18-01-2025       Printer  Electronics              3       15000
# 8  20-01-2025        Webcam  Accessories              7        3000
# 9  25-01-2025    Power Bank  Accessories             12        2000
#
#    Total Sales Region
# 0       275000  North
# 1       180000  South
# 2        37500   East
# 3        12000   West
# 4        72000  North
# 5        16000  South
# 6        88000   East
# 7        45000   West
# ...
