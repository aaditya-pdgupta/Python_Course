# %% [markdown]
# #### __name_Python
# ##### __name__ is a built in variable that tells Python how a file is being used.
# ##### It tells whether a Python file is:
# ##### 1.run directly or
# ##### 2. imported as module

# %%
import arth

# %%
a = 100  # Using the __name__ prevent the exceution of the previous executible code.
out = arth.square_root(a)

# %%
print(out)
# Out:
# 10000
