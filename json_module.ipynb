# %% [markdown]
# #### JSON
# ##### JSON(JavaScript Object Notation) is a lightweight data-exchange format used to store and transfer data.
#
# ##### Why Use json Module?
# ##### The json module in Python is used to:
# i> Convert Python objects ---->
