# %% [markdown]
# #### Multiple Inheritance
# ##### Multiple Inheritance means a single child class inherits features from more than one parent class.
# ##### Example
#
#                 Class A                 Class B
#                     -                      -
#                      - ---- Class C --------

# %%
# Single level Inheritance

# %%
class A:
     def state_1(self):
         print("State_1 is present")

     def state_2(self):
         print("State_2 is present")

     def state_2(self):
         print("State_3 is present")

class B:
    def state_4(self):
        print("State_4 is present")

# %%
# Multi Level Inheritance

# %%
class C:
    def state_6(self):
        print("State_6 is present")

# %%
a = A()

# %%
a.state_1()
# Out:
# State_1 is present

# %%
b = B()

# %%
b.state
