# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img = cv2.imread("highway.jpg")

# %%
w, h = img.shape[:2]
print("Original Image", w, "x", h)
# Out:
# Original Image 3333 x 5000

# %%
new_width = 256
ratio = new_width / w
new_height = int(h * ratio)

# %%
resized = cv2.resize(img, (new_width, new_height),  interpolation = cv2.INTER_AREA)

# %%
resized_rgb =cv2.cvtColor(resized, cv2.COLOR_BGR2RGB)
print("Resized Image", w, "x", h)
# Out:
# Resized Image 3333 x 5000

# %%
plt.imshow(resized_rgb)
plt.title("Original Image")
plt.axis("off")
# Out:
# (-0.5, 255.5, 383.5, -0.5)

# %%
new_width = 6666
ratio = new_width / w
new_height = int(h * ratio)

# %%
resized_1 = cv2.resize(img, (new_width, new_height),  interpolation = cv2.INTER_CUBIC)

# %%
resized_rgb_1 =cv2.cvtColor(resized_1, cv2.COLOR_BGR2RGB)

# %%
new_w, new_h = resized_1.shape[:2]
print("Resized image", new_w, "x", new_h)
# Out:
# Resized image 10000 x 6666

# %%
plt.imshow(resized_rgb_1)
plt.title("Original Image")
plt.axis("off")
# Out:
# (-0.5, 6665.5, 9999.5, -0.5)
