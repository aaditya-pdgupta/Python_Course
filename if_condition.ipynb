# %% [markdown]
# #### Conditional Statement in Python
# ##### Conditional statements allow our program to make decisions based on conditions.
# ##### if
# ##### if else
# ##### if elif else
# ##### Nested if
# ##### Short-hand if/ Ternary operator

# %% [markdown]
# #### if condition in Python
# ##### The if statement is used to run a block of code only when condition is true.
# ##### syntax:
#             if condition:
#                     statement

# %%
age = float(input("What is your age?:"))
# Out:
# What is your age?: 17

# %%
#print("age")

# %%
if age >= 18: # Here we have 21 years age so it is greater than 18 it will give true.
    print("Congrats! you are an adult. You can caste vote!!!")
