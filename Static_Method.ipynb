# %% [markdown]
# #### Static Method
# ##### A static metod is a method that belongs to a class but does not use instance (self) or class (cls) data. It behaves like a normal function, but is placed inside a class for logical grouping.
#
# nts

# %% [markdown]
# ##### Syntax
#
#                     class ClassName:
#                         @staticmethod
#                         def method_name(arguments):
#                             statements

# %%
class Student:
    college_name = "ABC College" 
    departments = ["Arts", "Commerce", "Science"]

    def __init__(self, name, roll): 
        self.name = name
        self.roll = roll

    def study(self, n_hours):
        print(self)
        print(f"{self.name} studies for {n_hours} hours a day ! ")
        
    def sports(self, sports_name):
        print(f"The student plays {sports_name} in the college {self.college_name}")

    @staticmethod
    def greeting():
        print(f"Welcome to the college !!") # Here the cls use for the class name and it fetch the class variable.

    @classmethod
    def get_department(cls):
        print(f"Departments in {cls.college_name} are:")
        for department in cls.departments:
            print(department)

# %%
#help(Student)

# %%
student1 = Student(name = "John", roll = 1021)

# %%
student1.greeting()
# Out:
# Welcome to the college !!

# %%
student1.study(3)
# Out:
# ...
# John studies for 3 hours a day !

# %%
student1.get_department()
# Out:
# Departments in ABC College are:
# Arts
# Commerce
# Science

# %%
student2 = Student(name = "Carrie", roll = 1022)

# %%
student2.greeting()
# Out:
# Welcome to the college !!

# %%
student2.get_department()
# Out:
# Departments in ABC College are:
# Arts
# Commerce
# Science

# %%
student2.study(5)
# Out:
# ...
# Carrie studies for 5 hours a day !
