# %%
print("Hello everyone! We are learning Python.")
# Out:
# Hello everyone! We are learning Python.

# %%
num = 10

# %%
num
# Out:
# 10

# %%
print(num)
# Out:
# 10

# %%
name = input("Enter your name:")
# Out:
# Enter your name: Aadi

# %%
age = int(input("What is your age:")) # Here we can directly convert string into the integer.
# Out:
# What is your age: 22

# %%
print(name,age)
# Out:
# Aadi 22

# %% [markdown]
# ### Numeric Function
# Numeric functions in Python are built in function used to work  with numbers (integers, float, complex number)

# %%
print(max(1,2,3,4)) # Gives the largest number from the list.
# Out:
# 4

# %%
print(min(1,2,3,4,66)) # Gives the smallest number from the list.
# Out:
# 1

# %%
print(abs(-2020)) # It gives the absolute value.
# Out:
# 2020

# %%
print(pow(10, 2)) #It gives the power of the number.
# Out:
# 100

# %%
print(sum([1,2,3])) # It gives the sum of the number but you need to use the big bracket along the small bracket.
# Out:
# 6

# %%
print(divmod(10, 3)) # It gives the quotient as well as remainder.
# Out:
# (3, 1)

# %%
print(round(3.2)) # It gives the round off value.
# Out:
# 3

# %% [markdown]
# ### Coding Exercise_1
# #### Area of Triangle

# %%
# When all the side is known:
# Semi-perimeter(s) = (a+b+c)/2
# Area = Square root of (s*(s-a)*(s-b)*(s-c))

# %%
a = float(input("Enter the first side:"))
# Out:
# Enter the first side: 7

# %%
b = float(input("Enter the second side:"))
# Out:
# Enter the second side: 8

# %%
c = float(input("Enter the third side:"))
# Out:
# Enter the third side: 9

# %%
s = (a + b + c)/2

# %%
area = (s*(s-a)*(s-b)*(s-c)) ** 0.5

# %%
print("The area is", area)
# Out:
# The area is 26.832815729997478

# %%
print("The area is", round(area, 2)) # we are taking the only 2 last value.
# Out:
# The area is 26.83

# %%
print("The area is", round(area, 0))
# Out:
# The area is 27.0

# %% [markdown]
# #### Calculation of the simple interest.

# %%
# SI=(P*T*R)/100

# %%
P = float(input("Enter the principal amount:"))
# Out:
# Enter the principal amount: 1000

# %%
T = float(input("Enter the time:"))
# Out:
# Enter the time: 5

# %%
R = float(input("Enter the rate:"))
# Out:
# Enter the rate: 5

# %%
si = (P*T*R)/100

# %%
print("The simple interest is", si)
# Out:
# The simple interest is 250.0

# %% [markdown]
# #### Calculation of Compound Interest

# %%
# Amount =p(1+r/100)**t
#ci = A-P

# %%
P = float(input("Enter the principal amount:"))
# Out:
# Enter the principal amount: 10001

# %%
T = float(input("Enter the time:"))
# Out:
# Enter the time: 5

# %%
R = float(input("Enter the rate:"))
# Out:
# Enter the rate: 5

# %%
Amount = P * (1 + R/100) ** T

# %%
ci = Amount - P

# %%
print("The compound interest is:", round(ci,2))
# Out:
# The compound interest is: 2763.09

# %% [markdown]
# ### Calculate the area for the right angled triangle

# %%
#Area=1/2*b*h

# %%
a = float(input("Enter the base:"))
# Out:
# Enter the base: 30

# %%
b = float(input("Enter the height:"))
# Out:
# Enter the height: 50

# %%
area = 1/2 * b * a

# %%
print("The area of the right angled triangle is", round(area, 2))
# Out:
# The area of the right angled triangle is 750.0
