# %% [markdown]
# #### Picle Module
# ##### The pickle module is a built in Python module used to serialize and deserialize Python objects.
#
# ##### 1.It saves Python objects into a binary file.
# ##### 2. It retrieves them back in their original form.
# ##### 3. Used to store complex objects and machine learning models.
#
# ##### Fuctions:
# ##### 1. pickle.dump() -----> save object.
# ##### 2. pickle.load() -----> load object

# %%
import pickle

# %%
students = {"student1": {"roll": 101, "name": "John", "percent": 98.5},
             "student2": {"roll": 102, "name": "Carol", "percent": 92.5},
             "student3": {"roll": 103, "name": "Alice", "percent": 80.0}}

# %%
print(students)
# Out:
# {'student1': {'roll': 101, 'name': 'John', 'percent': 98.5}, 'student2': {'roll': 102, 'name': 'Carol', 'percent': 92.5}, 'student3': {'roll': 103, 'name': 'Alice', 'percent': 80.0}}

# %%
print(type(students))
# Out:
# <class 'dict'>

# %%
# Seriization

# %%
with open("student.bin", "bw") as fh:
    for student in students:
        pickle.dump(student, fh)

# %%
#Deserialization

# %%
with open("student.bin", "rb") as fh:
    data = pickle.load(fh)
    print(data
