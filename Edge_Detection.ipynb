# %% [markdown]
# #### Edge Detection
# ##### Edge detection is a technique in image processing used to identify boundaries of object in an image. Common Edge detection methods are:
# ##### 1. Canny Edge Detection (Most Popular)
# ##### Steps in Cannny are :
# - Noise ireduction
