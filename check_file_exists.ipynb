# %%
import os

# %%
file_name = Python_Course/Practice.txt

# %%
if os.path.exists(file_name):
    print("File exists")
else:
    print("File does not exist")
# Out:
# File exists

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 file = Python_Course/Practice.txt
#
# NameError: name 'Python_Course' is not defined
