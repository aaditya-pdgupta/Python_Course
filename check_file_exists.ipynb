# %%
import os

# %%
file_name = "Practice.txt"

# %%
if os.path.exists(file_name):
    print("File exist, Cannot create!!")
else:
    print("File does not exist, creating a file")
    fh = open("Practice.txt", "x")
    fh.write("Some Content")
    fh.close()
# Out:
# File exist, Cannot create!!
