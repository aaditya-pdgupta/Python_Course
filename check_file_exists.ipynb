# %%
import os

# %%
file_name = "Practice.txt"

# %%
if os.path.exists(file_name):
    print("File exist")
else:
    print("File does not exist")
# Out:
# File exist

# %%
# pathlib.Path.exists()

# %%
file = "Practice.txt"

# %%
if fle_name
