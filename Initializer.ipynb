# %% [markdown]
# #### Initializer in Python
# ##### An initializer is a special method that automatically runs when an object is created. In Python, the initializer is called initializer.
#
# ##### Initializer = method that sets initial values of an object. It is an instance method
# __ init __
