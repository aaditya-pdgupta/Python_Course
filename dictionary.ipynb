# %% [markdown]
# #### Dictionary in Python
# ##### A dictionary is a collection of key-value pairs. Each value is accessed using its key, not an index.
# ##### Syntax:
#                 my_dict = {
#                      "name": "Aadi",
#                       "age": 20,
#                        "country": "India"
#                     }

# %%
#{key

# %%
groceries = {"milk": 60, "biscuits": 20, "rice" : 90, "bread" : 30}
