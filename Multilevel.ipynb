# %% [markdown]
# #### Multilevel Inheritance
# ##### Multilevel inheritance is a type of inheritance where a class is derived from another derived class ---- forming a chain of inheritance.
#
# ##### Strucrture
# ##### Grandparent----> Parent-----> Child

# %%
class Vehicle:
    company = "XYZ Motors"

    def __init__(self, n_wheels, n_seats, mileage):
        print("init of Vehicles")
        self.n_wheels = n_wheels
        self.n_seats = n_seats
        self.mileage = mileage
        
    def get_details(self):
        return f"This vehicle has {self.n_wheels} wheels, {self.n_seats} seats and provoide a mileage of {self.mileage}"

# %%
class Car(Vehicle):
    model = "ABC123"
    def __init__(self, car_type, drive_type, wheels, seats, mileage):
        print("init of Car")
        self.car_type = car_type
        self.drive_type = drive_type
        super().__init__(wheels, seats, mileage)
        
    def display_info(self):
        print(f"Car type: {self.car_type}, Drive type :{self.drive_type}")

# %%
class ElectricCar(Car):
    def __init__(self, car_type, drive_type, wheels, seats, mileage, battery_capacity, distance_range):
        print("init of ElectricCar")
        self.battery_capacity = battery_capacity
        self.distance_range = distance_range
        super().__init__(car_type, drive_type, wheels, seats, mileage)
        
    def charge(self):
        print(f"Charging the to {self.battery_capacity}")

# %%
ec1 = ElectricCar(car_type = "Tata", drive_type = "Manual", wheels = 4, seats = 5, mileage = 4, battery_capacity = 100, distance_range = 300)
# Out:
# init of ElectricCar
# init of Car
# init of Vehicles

# %%
print(ec1.__dict__)
# Out:
# {'battery_capacity': 100, 'distance_range': 300, 'car_type': 'Tata', 'drive_type': 'Manual', 'n_wheels': 4, 'n_seats': 5, 'mileage': 4}

# %%
help(ElectricCar)
# Out:
# Help on class ElectricCar in module __main__:
#
# class ElectricCar(Car)
#  |  ElectricCar(car_type, drive_type, wheels, seats, mileage, battery_capacity, distance_range)
#  |
#  |  Method resolution order:
#  |      ElectricCar
#  |      Car
#  |      Vehicle
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, car_type, drive_type, wheels, seats, mileage, battery_capacity, distance_range)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  charge(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Car:
#  |
#  |  display_info(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from Car:
#  |
#  |  model = 'ABC123'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Vehicle:
#  |
#  |  get_details(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from Vehicle:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from Vehicle:
#  |
#  |  company = 'XYZ Motors'
