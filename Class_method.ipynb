# %% [markdown]
# #### Class Method
# ##### A class method is a method that is bound to the class, not to an object. It can access and modify class variables. It uses cls as the first parameter and is defined using the @classmethod decorator.
#
#           entsts

# %% [markdown]
# ##### Class Method Syntax
#
# ```python
# class ClassName:
#     @classmethod
#     def method_name(cls, arguments):
#         statements

# %%
class Welcome:
    @classmethod
    def greet(cls): # here we have class method greet. 
        print("HEllo")

# %%
w1 = Welcome()

# %%
w1.greet()
# Out:
# HElo

# %%
print(Welcome)
# Out:
# <class '__main__.Welcome'>

# %%
class Student:
    college_name = "ABC College" 
    departments = ["Arts", "Commerce", "Science"]

    def __init__(self, name, roll): 
        self.name = name
        self.roll = roll

    def study(self, n_hours):
        print(self)
        print(f"The student studies for {n_hours} hours a day ! ")
        
    def sports(self, sports_name):
        print(f"The student plays {sports_name} in the college {self.college_name}")

    @classmethod
    def greeting(cls):
        print(cls)
        print(f"Welcome to the college {cls.college_name}!!") # Here the cls use for the class name and it fetch the class variable.

    @classmethod
    def get_department(cls):
        print(f"Departments in {cls.college_name} are:")
        for department in cls.departments:
            print(department)

# %%
student1 = Student(name = "John", roll = "1111")

# %%
student1.study(3)
# Out:
# ...
# The student studies for 3 hours a day !

# %%
# Now we need to call the class method.

# %%
student1.greeting()
# Out:
# <class '__main__.Student'>
# Welcome to the college ABC College!!

# %%
student1.sports("Football")
# Out:
# The student plays Football in the college ABC College

# %%
student1.get_department()
# Out:
# Departments in ABC College are:
# Arts
# Commerce
# Science
