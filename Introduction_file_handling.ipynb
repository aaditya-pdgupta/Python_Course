# %% [markdown]
# #### File Handling
# ##### File handling in python is used to store, read and modify data permanently using the files.
# #### Files Modes
# ##### r -----> read
# ##### w -----> write
# ##### a -----> append
# ##### rt ----> read & write
#
# #### 1. Text Files
# ##### It stores data in human readable form.  examples. .txt, .csv
#
# #### 2. Binary Files
# ##### It stores data in binary (0s and 1s). examples: images, audio, medical signal files etc.
#
#
# #### Opening a File
# ##### file = open(file_name, files_modes_to_open)

# %%
file_handler = open("Practice.txt", "rt") # Here rt is default mode means if we don't give the command than also it get executed automatically.

# %%
print(file_handler)
# Out:
# <_io.TextIOWrapper name='Practice.txt' mode='rt' encoding='cp1252'>

# %%
# Read Operation

# %%
# Closing a file ===> close()

# %%
file_handler.close()

# %%
print(
