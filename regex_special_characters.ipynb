# %%
import re

# %%
s1 = "Python is a programming language."

# %%
# [A-Z], [a-z]

# %%
#p = r"old\new"

# %%
#print(p) # Here the output is printed as backslash without breaking the line.

# %%
pat = r"[a-z][a-z]" # The r stands for raw. It tells Python: Don't treat backslashes(\) as escape characters.

# %%
match_object = re.search(pat, s1)

# %%
print(match_object)
# Out:
# <re.Match object; span=(1, 3), match='yt'>

# %%
# Now let use another case

# %%
pa = r"[A-Z][a-z][a-z]"

# %%
match = re.search(pa, s1)

# %%
print(match)
# Out:
# <re.Match object; span=(0, 3), match='Pyt'>

# %%
# \d mean Digit and \D mean Non-Digit

# %%
# \d matches 1  digit character. It is similar [0-9]

# %%
s2 = "Python is a programming Language. python3.13 is the current version."

# %%
p = r"[a-z][a-z][a-z]\d" # This mean three lowercase letters followed by one digit.

# %%
match_obj = re.search(p, s2)

# %%
print(match_obj) # So here the hon is followed by 3.13 .
# Out:
# <re.Match object; span=(37, 41), match='hon3'>

# %%
# \D matches 1 non-digit character. It is similar to [0-9]

# %%
paa = r"[a-z][a-z][a-z]\D" # It is just opposite of the small d it matches with anything except numbers.

# %%
m = re.search(paa, s2)

# %%
print(m)
# Out:
# <re.Match object; span=(1, 5), match='ytho'>

# %%
#\s matches any whitespace character. They can be the space, tab, newline etc.

# %%
pp = r"[a-z][a-z][a-z]\s"

# %%
mt = re.search(pp, s2)

# %%
print(mt) # Here it is matching space.
# Out:
# <re.Match object; span=(3, 7), match='hon '>

# %%
s3 = """Hi there
We are learning Python.
"""

# %%
print(s3)
# Out:
# Hi there
# We are learning Python.

# %%
ppt = r"[a-z][a-z][a-z]\s" #Here it is matching new line character.

# %%
m = re.search(ppt, s3)

# %%
print(m)
# Out:
# <re.Match object; span=(5, 9), match='ere\n'>

# %%
#\S mathes any non-whitespace character.

# %%
ppt = r"[a-z][a-z][a-z]\S"

# %%
m = re.search(ppt, s3)

# %%
print(m)
# Out:
# <re.Match object; span=(3, 7), match='ther'>

# %%
# \w --> A word character that includes only letters[a-z], [A-Z], Digits (0-9), undedrscore.

# %%
ppt = r"[a-z][a-z][a-z]\w"

# %%
m = re.search(ppt, s3)

# %%
print(m)
# Out:
# <re.Match object; span=(3, 7), match='ther'>

# %%
# \W ---> not a word character. It matches everything except letters[a-z], [A-Z], Digits (0-9), undedrscore.

# %%
ppt = r"[a-z][a-z][a-z]\W"

# %%
m = re.search(ppt, s3)

# %%
print(m)
# Out:
# <re.Match object; span=(5, 9), match='ere\n'>
