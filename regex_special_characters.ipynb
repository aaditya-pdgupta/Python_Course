# %%
import re

# %%
s1 = "Python is a programming language."

# %%
# [A-Z], [a-z]

# %%
pat = r""

# %%
match_object = re.search()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 match_object = re.search()
#
# TypeError: search() missing 2 required positional arguments: 'pattern' and 'string'
