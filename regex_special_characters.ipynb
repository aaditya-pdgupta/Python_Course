# %%
import re

# %%
s1 = "Python is a programming language."

# %%
# [A-Z], [a-z]

# %%
pat = r"" # The r stands for raw. It tells Python: Don't treat backslashes(\) as escape characters.

# %%
#match_object = re.search()
